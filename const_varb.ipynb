# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmasimran/tensorflow_learnings/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==1.13.1
# Out:
# ...
#      |████████████████████████████████| 345.2MB 40kB/s
# ...
#      |████████████████████████████████| 3.2MB 51.5MB/s
# ...
#      |████████████████████████████████| 368kB 51.0MB/s
# ...
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.13.1 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.13.0 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# ...

# %%
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
# !pip install tensorflow-gpu==2.0.0-alpha0
# Out:
# ...
#      |████████████████████████████████| 332.1MB 25kB/s
# ...
#      |████████████████████████████████| 419kB 46.1MB/s
# ...
#      |████████████████████████████████| 3.0MB 44.4MB/s
# ...

# %%
# !pip uninstall -y tensorflow
# Out:
# Uninstalling tensorflow-2.2.0:
#   Successfully uninstalled tensorflow-2.2.0

# %%
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 516.2MB 25kB/s
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
tfconst= tf.constant([[23,4],[32,51]])

# %%
tfconst
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23,  4],
#        [32, 51]], dtype=int32)>

# %%
tfconst.shape
# Out:
# TensorShape([2, 2])

# %%
tfconst.numpy()
# Out:
# array([[23,  4],
#        [32, 51]], dtype=int32)

# %%
import numpy as np

# %%
numpy_tensor= np.array([[23,8],[67,3]])

# %%
numpy_tensor
# Out:
# array([[23,  8],
#        [67,  3]])

# %%
tensor_from_numpy= tf.constant(numpy_tensor)

# %%
tensor_from_numpy
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int64, numpy=
# array([[23,  8],
#        [67,  3]])>

# %%
tfvar= tf.Variable([[23,89],[5,78]])

# %%
tfvar
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=int32, numpy=
# array([[23, 89],
#        [ 5, 78]], dtype=int32)>

# %%
tfvar.numpy()
# Out:
# array([[23, 89],
#        [ 5, 78]], dtype=int32)

# %%
tfconst +2
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[25,  6],
#        [34, 53]], dtype=int32)>

# %%
tfconst
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23,  4],
#        [32, 51]], dtype=int32)>

# %%
tfconst*5
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[115,  20],
#        [160, 255]], dtype=int32)>

# %%
np.square(tfconst)
# Out:
# array([[ 529,   16],
#        [1024, 2601]], dtype=int32)

# %%
np.sqrt(tfconst)
# Out:
# array([[4.79583152, 2.        ],
#        [5.65685425, 7.14142843]])

# %%
tfstring =tf.constant("Tensorflow 2.0")

# %%
tfstring
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'Tensorflow 2.0'>

# %%
tf.strings.length(tfstring)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=14>

# %%
#decoding string
tf.strings.unicode_decode(tfstring,"UTF8")
# Out:
# <tf.Tensor: shape=(14,), dtype=int32, numpy=
# array([ 84, 101, 110, 115, 111, 114, 102, 108, 111, 119,  32,  50,  46,
#         48], dtype=int32)>

# %%
tfstringarray= tf.constant(["simran","sharma","rahul","suresh"])

# %%
for i in tfstringarray:
  print(i)
# Out:
# tf.Tensor(b'simran', shape=(), dtype=string)
# tf.Tensor(b'sharma', shape=(), dtype=string)
# tf.Tensor(b'rahul', shape=(), dtype=string)
# tf.Tensor(b'suresh', shape=(), dtype=string)

# %%
for i in tfstringarray:
  print(tf.strings.unicode_decode(i,"UTF8"))
# Out:
# tf.Tensor([115 105 109 114  97 110], shape=(6,), dtype=int32)
# tf.Tensor([115 104  97 114 109  97], shape=(6,), dtype=int32)
# tf.Tensor([114  97 104 117 108], shape=(5,), dtype=int32)
# tf.Tensor([115 117 114 101 115 104], shape=(6,), dtype=int32)

# %%
for i in tfstringarray:
  print(tf.strings.length(i))
# Out:
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
